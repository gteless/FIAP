# %%
import yfinance as yf

# %%
import yfinance as yf

ticker = "BBAS3.SA"
dados = yf.download(ticker, start="2019-01-01", end="2025-09-30")

print(dados.head())
# Out:
# Failed to get ticker 'BBAS3.SA' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BBAS3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
